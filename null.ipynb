# %%
import pandas as pd
import numpy as np

# %%
obj = {
    'student_id' : ['s1','s2','s3','s4','s5','s6'],
    'stat_score' : [None,90,85,71,None,99],
    'math_score' : [65,None,87,75,57,88],
    'gender' : ['F','M','F',None,'M','M'],
    'pre_level': ['B','A','B','B','C',None]
}

# %%
df = pd.DataFrame(obj)

# %%
# 결측치 여부 확인 : isnull
df.isnull()
# Out:
#    student_id  stat_score  math_score  gender  pre_level
# 0       False        True       False   False      False
# 1       False       False        True   False      False
# 2       False       False       False   False      False
# 3       False       False       False    True      False
# 4       False        True       False   False      False
# 5       False       False       False   False       True

# %%
# 응용 결측치 수 확인
df.isnull().sum()
# Out:
# student_id    0
# stat_score    2
# math_score    1
# gender        1
# pre_level     1
# dtype: int64

# %%
## 결측치 처리 1 제거 : dropna()
df2 = df.copy()

df2.dropna()
# Out:
#   student_id  stat_score  math_score gender pre_level
# 2         s3        85.0        87.0      F         B

# %%
## 결측치 처리 1 응용
df3 = df.copy()

# %%
df3['stat_score'].dropna()
# Out:
# 1    90.0
# 2    85.0
# 3    71.0
# 5    99.0
# Name: stat_score, dtype: float64

# %%
## 결측치 채우기 : fillna

df4 = df.copy()

df4.fillna(0,inplace = True)

# %%
df4
# Out:
#   student_id  stat_score  math_score gender pre_level
# 0         s1         0.0        65.0      F         B
# 1         s2        90.0         0.0      M         A
# 2         s3        85.0        87.0      F         B
# 3         s4        71.0        75.0      0         B
# 4         s5         0.0        57.0      M         C
# 5         s6        99.0        88.0      M         0
