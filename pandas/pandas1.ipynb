# %%
import pandas as pd
import numpy as np

# %%
obj = ['임꺽정' , '정발산' , '산기슭']
se1 = pd.Series(obj)

# %%
se1
# Out:
# 0    임꺽정
# 1    정발산
# 2    산기슭
# dtype: object

# %%
idx = ['A','B','C']
se1.index = idx

# %%
se1
# Out:
# A    임꺽정
# B    정발산
# C    산기슭
# dtype: object

# %%
se2 = pd.Series(obj , idx)

# %%
se2
# Out:
# A    임꺽정
# B    정발산
# C    산기슭
# dtype: object

# %%
obj = {'A' : '임꺽정' , 'B' : '정발산' , 'C' : '산기슭' }

# %%
se3 = pd.Series(obj)

# %%
se3
# Out:
# A    임꺽정
# B    정발산
# C    산기슭
# dtype: object

# %%
## 객체 values
se3.values
# Out:
# array(['임꺽정', '정발산', '산기슭'], dtype=object)

# %%
## 객체 index
se3.index
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
## 데이터 타입보기 dtyped
se3.dtypes
# Out:
# dtype('O')

# %%
## describe
se3.describe()
# Out:
# count       3
# unique      3
# top       임꺽정
# freq        1
# dtype: object

# %%
## count
se3.count()
# Out:
# 3

# %%
se4 = pd.Series(np.arange(100))

# %%
se4.describe()
# Out:
# count    100.000000
# mean      49.500000
# std       29.011492
# min        0.000000
# 25%       24.750000
# 50%       49.500000
# 75%       74.250000
# max       99.000000
# dtype: float64

# %%
se4.max()
# Out:
# 99

# %%
se4.min()
# Out:
# 0
