# %%
import pandas as pd
import numpy as np

# %%
obj = {
    '이름' : ['임꺽정' , '정발산' ,'산기슭'],
    '성별' : ['남' ,'남','남'],
    '나이' : [25,20,30]
}

# pd.DataFrame(obj)

df = pd.DataFrame(obj)

# %%
df
# Out:
#     이름 성별  나이
# 0  임꺽정  남  25
# 1  정발산  남  20
# 2  산기슭  남  30

# %%
# 데이터 프레임 객체.obj
df['이름'].values
# Out:
# array(['임꺽정', '정발산', '산기슭'], dtype=object)

# %%
df.values
# Out:
# array([['임꺽정', '남', 25],
#        ['정발산', '남', 20],
#        ['산기슭', '남', 30]], dtype=object)

# %%
# 데이터 프레임 index
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df['이름'].index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# 데이터 프레임 columns
df.columns
# Out:
# Index(['이름', '성별', '나이'], dtype='object')

# %%
# 데이터 프레임 shape
df.shape
# Out:
# (3, 3)

# %%
# 데이터 정보 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      3 non-null      object
#  1   성별      3 non-null      object
#  2   나이      3 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
# 데이터 머리말 , 끝 확인

display(df.head())
display(df.tail())
# Out:
#     이름 성별  나이
# 0  임꺽정  남  25
# 1  정발산  남  20
# 2  산기슭  남  30
#     이름 성별  나이
# 0  임꺽정  남  25
# 1  정발산  남  20
# 2  산기슭  남  30

# %%
df.loc[df['나이'] == 20 , :]
# Out:
#     이름 성별  나이
# 1  정발산  남  20

# %%
df[['이름' , '성별']]
# Out:
#     이름 성별
# 0  임꺽정  남
# 1  정발산  남
# 2  산기슭  남

# %%
df.iloc[1]
# Out:
# 이름    정발산
# 성별      남
# 나이     20
# Name: 1, dtype: object

# %%
df.iloc[0:2]
# Out:
#     이름 성별  나이
# 0  임꺽정  남  25
# 1  정발산  남  20

# %%
idx = [0,2]
df.iloc[idx]
# Out:
#     이름 성별  나이
# 0  임꺽정  남  25
# 2  산기슭  남  30

# %%
df['나이'].count()
# Out:
# 3

# %%
df['나이'].mean()
# Out:
# 25.0

# %%
df['나이'].quantile(q = 0.5)
# Out:
# 25.0

# %%
df['나이'].var()
# Out:
# 25.0

# %%
df['나이'].std()
# Out:
# 5.0

# %%
df['나이'].median()
# Out:
# 25.0
