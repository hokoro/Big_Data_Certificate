# %% [markdown]
# ## Q. 2022년 데이터 중 2022년 중앙값보다 큰 값의 데이터 수

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/빅데이터 분석기사/data/t1-data2.csv')
df
# Out:
#     year   0   1   2   3   4   5    6   7   8  ...  90  91  92  93  94  95  \
# 0  2022년  69  37  57  70  40  75    8  67  89  ...  79  56  98  21  14  25
# 1  2023년  52  13  22  70  92  80    8  56  17  ...  62  47  59   6  25  96
# 2  2024년  88  44  32  55  64   8    4   2  62  ...  98  95  40  59  69  71
# 3  2025년  80  97  15   4  74  12  100  60  47  ...  30  11   2  54   9  52
# 4  2026년  64  66  62  56  67  80   90  24  58  ...  93  15  88  67   7  82
#
#    96  97  98  99
# 0  17  10  60  17
# 1  69  87  28  64
# 2  86  53  93  64
# 3  51  81  78  22
# 4   5  61  15  63
#
# [5 rows x 101 columns]

# %%
df = df.T

# %%
df
# Out:
#           0      1      2      3      4
# year  2022년  2023년  2024년  2025년  2026년
# 0        69     52     88     80     64
# 1        37     13     44     97     66
# 2        57     22     32     15     62
# 3        70     70     55      4     56
# ...     ...    ...    ...    ...    ...
# 95       25     96     71     52     82
# 96       17     69     86     51      5
# 97       10     87     53     81     61
# 98       60     28     93     78     15
# 99       17     64     64     22     63
#
# [101 rows x 5 columns]

# %%
df.iloc[0]
# Out:
# 0    2022년
# 1    2023년
# 2    2024년
# 3    2025년
# 4    2026년
# Name: year, dtype: object

# %%
df.columns = df.iloc[0]

# %%
df.drop('year',axis = 0,inplace = True)

# %%
df
# Out:
# year 2022년 2023년 2024년 2025년 2026년
# 0       69    52    88    80    64
# 1       37    13    44    97    66
# 2       57    22    32    15    62
# 3       70    70    55     4    56
# 4       40    92    64    74    67
# ..     ...   ...   ...   ...   ...
# 95      25    96    71    52    82
# 96      17    69    86    51     5
# 97      10    87    53    81    61
# 98      60    28    93    78    15
# 99      17    64    64    22    63
#
# [100 rows x 5 columns]

# %%
median_ = df['2022년'].median()
len(df[df['2022년'] > median_][:])
# Out:
# 50

# %%
median_
# Out:
# 54.5

# %%
df.loc[df['2022년'] > median_].shape[0]
# Out:
# 50
