# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##작업형1 문제
# - 1-1. age 컬럼의 3사분위수와 1사분위수의 차를 절대값으로 구하고, 소수점 버려서, 정수로 출력

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/drive/MyDrive/빅데이터 분석기사/data/basic3.csv')

# %%
df
# Out:
#        id    age city    f1  f2   f3    f4         f5
# 0    id01    2.0   서울   NaN   0  NaN  ENFJ  91.297791
# 1    id02    9.0   서울  70.0   1  NaN  ENFJ  60.339826
# 2    id03   27.0   서울  61.0   1  NaN  ISTJ  17.252986
# 3    id04   75.0   서울   NaN   2  NaN  INFP  52.667078
# 4    id05   24.0   서울  85.0   2  NaN  ISFJ  29.269869
# ..    ...    ...  ...   ...  ..  ...   ...        ...
# 95   id96   92.0   경기  53.0   1  NaN  ENTJ  52.667078
# 96   id97  100.0   경기   NaN   0  NaN  INFP  67.886373
# 97   id98   39.0   경기  58.0   2  NaN  INFP  98.429899
# 98   id99    1.0   경기  47.0   0  NaN  ESFJ  97.381034
# 99  id100   47.0   경기  53.0   0  vip  ESFP  33.308999
#
# [100 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# id       0
# age      0
# city     0
# f1      31
# f2       0
# f3      95
# f4       0
# f5       0
# dtype: int64

# %%
age = df['age']

# %%
age
# Out:
# 0       2.0
# 1       9.0
# 2      27.0
# 3      75.0
# 4      24.0
#       ...
# 95     92.0
# 96    100.0
# 97     39.0
# 98      1.0
# 99     47.0
# Name: age, Length: 100, dtype: float64

# %%
age = age.sort_values()

# %%
age.max() , age.min()
# Out:
# (100.0, -13.5)

# %%
Q3 = age.quantile(0.75)
Q1 = age.quantile(0.25)

# %%
answer = int(abs(Q3-Q1))
answer
# Out:
# 50

# %% [markdown]
# ## 작업형 1-2문제
# - 1-2.(loves반응+wows반응)/(reactions반응) 비율이 0.4보다 크고 0.5보다 작으면서, type 컬럼이 'video'인 데이터의 갯수

# %%
df2 = pd.read_csv('/content/drive/MyDrive/빅데이터 분석기사/data/fb.csv')
df2
# Out:
#         id   type  reactions  comments  shares  likes  loves  wows  hahas  \
# 0        1  video        529       512     262    432     92     3      1
# 1        2  photo        150         0       0    150      0     0      0
# 2        3  video        227       236      57    204     21     1      1
# 3        4  photo        111         0       0    111      0     0      0
# 4        5  photo        213         0       0    204      9     0      0
# ...    ...    ...        ...       ...     ...    ...    ...   ...    ...
# 7045  7046  photo         89         0       0     89      0     0      0
# 7046  7047  photo         16         0       0     14      1     0      1
# 7047  7048  photo          2         0       0      1      1     0      0
# 7048  7049  photo        351        12      22    349      2     0      0
# 7049  7050  photo         17         0       0     17      0     0      0
#
#       sads  angrys
# 0        1       0
# 1        0       0
# ...

# %%
df2.isnull().sum()
# Out:
# id           0
# type         0
# reactions    0
# comments     0
# shares       0
# likes        0
# loves        0
# wows         0
# hahas        0
# sads         0
# angrys       0
# dtype: int64

# %%
len(df2.loc[(df2['type']=='video') & (0.4<(df2['loves'] + df2['wows'])/(df2['reactions'])) & ((df2['loves'] + df2['wows'])/(df2['reactions']) <0.5) ,:])
# Out:
# 90

# %% [markdown]
# ## 작업형 1-3 문제
# 1-3. date_added가 2018년 1월 이면서 country가 United Kingdom 단독 제작인 데이터의 갯수

# %%
df3 = pd.read_csv('/content/drive/MyDrive/빅데이터 분석기사/data/nf.csv')
df3
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
len(df3[df3['date_added'].str.contains('January') & df3['date_added'].str.contains('2018') &(df3['country'] == 'United Kingdom')])
#print(len(  ))
# Out:
# 6
