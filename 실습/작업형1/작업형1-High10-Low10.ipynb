# %% [markdown]
# ## 상위 10 하위 10
# - 주어진 데이터에서 상위 10개 국가의 접종률 평균과 하위 10개 국가의 접종률 평균을 구하고, 그 차이를 구해보세요
# - (단, 100%가 넘는 접종률 제거, 소수 첫째자리까지 출력)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/빅데이터 분석기사/data/High10 Low10/covid-vaccination-vs-death_ratio.csv')

# %%
df
# Out:
#        Unnamed: 0      country iso_code        date  total_vaccinations  \
# 0               0  Afghanistan      AFG  2021-05-11            504502.0
# 1               1  Afghanistan      AFG  2021-05-20            547901.0
# 2               2  Afghanistan      AFG  2021-05-24            573277.0
# 3               3  Afghanistan      AFG  2021-05-26            590454.0
# 4               4  Afghanistan      AFG  2021-05-27            593313.0
# ...           ...          ...      ...         ...                 ...
# 32906       32906     Zimbabwe      ZWE  2022-03-25           8691642.0
# 32907       32907     Zimbabwe      ZWE  2022-03-26           8791728.0
# 32908       32908     Zimbabwe      ZWE  2022-03-27           8845039.0
# 32909       32909     Zimbabwe      ZWE  2022-03-28           8934360.0
# 32910       32910     Zimbabwe      ZWE  2022-03-29           9039729.0
#
#        people_vaccinated  people_fully_vaccinated  New_deaths  population  \
# ...

# %%
df_group_country = df.groupby('country',as_index = False)['ratio'].max()

# %%
df_group_country
# Out:
#                                                country      ratio
# 0                                          Afghanistan  12.589141
# 1                                              Albania  44.565704
# 2                                              Algeria  16.559294
# 3                                              Andorra  74.742421
# 4                                               Angola  32.503047
# ..                                                 ...        ...
# 192                                  Wallis and Futuna  58.436993
# 193                                              Yemen   2.083710
# 194                                             Zambia  12.928235
# 195                                           Zimbabwe  33.178924
# 196  occupied Palestinian territory, including east...  37.704650
#
# [197 rows x 2 columns]

# %%
df2 = df_group_country.sort_values('ratio',ascending = False)

# %%
df2 = df2.loc[df2['ratio']<=100 , :]

# %%
df2
# Out:
#                   country      ratio
# 184  United Arab Emirates  98.397065
# 140              Portugal  95.204947
# 45                   Cuba  93.972331
# 38                  Chile  92.654748
# 27      Brunei Darussalam  91.899582
# ..                    ...        ...
# 135      Papua New Guinea   3.439691
# 193                 Yemen   2.083710
# 37                   Chad   1.639191
# 76                  Haiti   1.408404
# 30                Burundi   0.083178
#
# [194 rows x 2 columns]

# %%
print(np.round(df2.iloc[:10].mean() - df2.iloc[-10:].mean() , 1))
# Out:
# ratio    88.4
# dtype: float64
# <ipython-input-23-ccee3fd0c798>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(np.round(df2.iloc[:10].mean() - df2.iloc[-10:].mean() , 1))
# <ipython-input-23-ccee3fd0c798>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(np.round(df2.iloc[:10].mean() - df2.iloc[-10:].mean() , 1))

# %%
df2.iloc[-10:].mean()
# Out:
# <ipython-input-21-386e73890f30>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.iloc[-10:].mean()
# ratio    3.450408
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/빅데이터 분석기사/data/High10 Low10/covid-vaccination-vs-death_ratio.csv')
# print(df.head())

df2 = df.groupby('country').max() #시간에 따라 접종률이 점점 올라감
df2 = df2.sort_values(by='ratio', ascending = False)

#100%가 넘는 접종률 제거
cond = df2['ratio'] <= 100
df2 = df2[cond]

top = df2['ratio'].head(10).mean()
bottom = df2['ratio'].tail(10).mean()

print(round(top - bottom,1))
# 결과값은 데이터 업데이트에 따라 달라질 수
# Out:
# 88.4
