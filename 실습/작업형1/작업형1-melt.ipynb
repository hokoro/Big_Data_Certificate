# %% [markdown]
# ## Q. 수학, 영어, 국어 점수 중 사람과 과목에 상관없이 가장 상위 점수 5개를 모두 더하고 출력하시오.

# %%
import pandas as pd
df = pd.DataFrame({'Name': {0: '김딴짓', 1: '박분기', 2: '이퇴근'},
                   '수학': {0: 90, 1: 93, 2: 85},
                   '영어': {0: 92, 1: 84, 2: 86},
                   '국어': {0: 91, 1: 94, 2: 83},})

df
# Out:
#   Name  수학  영어  국어
# 0  김딴짓  90  92  91
# 1  박분기  93  84  94
# 2  이퇴근  85  86  83

# %%
df = pd.melt(df, id_vars = ['Name'])

# %%
df = df.sort_values(by = 'value',ascending=False)

# %%
print(df['value'].iloc[:5])
# Out:
# 7    94
# 1    93
# 3    92
# 6    91
# 0    90
# Name: value, dtype: int64

# %%
score = []
for val in df.values:
    score.append(val[2])

# %%
score.sort(reverse = True)

# %%
sum(score[:5])
# Out:
# 460

# %%
df2 = pd.melt(df , id_vars = ['Name'] , value_vars = ['수학' ,'영어']) # id_vars = 기준  / value_vars = 사용하는 변수

# %%
df2
# Out:
#   Name variable  value
# 0  김딴짓       수학     90
# 1  박분기       수학     93
# 2  이퇴근       수학     85
# 3  김딴짓       영어     92
# 4  박분기       영어     84
# 5  이퇴근       영어     86
