# %% [markdown]
# ## 작업형 1번
# Pclass, Gender, sibsp, parch를 독립변수로 사용하여 로지스틱 회귀모형을 실시하였을 때, parch변수의 계수값은?
# (반올림하여 소수 셋째 자리까지 계산)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/빅데이터 분석기사/data/titanic/train.csv')

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
model.intercept_
# Out:
# array([2.02953505])

# %%
model.coef_[0][2]
# Out:
# -0.04398284404850206

# %%
x.columns
# Out:
# Index(['Pclass', 'SibSp', 'Parch', 'Sex_female', 'Sex_male'], dtype='object')

# %%
np.round(model.coef_[0][2],3)
# Out:
# -0.044
